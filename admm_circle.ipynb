# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
data0 = pd.read_csv("data/data0.txt", header=None, sep=" ")
data0[:5]
# Out:
#           0         1
# 0  1.253911  0.620272
# 1  1.248282  0.690882
# 2  1.264691  0.622266
# 3  1.241699  0.745910
# 4  1.218908  0.779448

# %%
plt.axis([0, 1.5, 0, 1.5])
plt.plot(data0[0], data0[1], 'o')

# %%
# parameters
ksi1 = 0.4
ksi2 = 0.4
r = 1
a = 0
b = 0
